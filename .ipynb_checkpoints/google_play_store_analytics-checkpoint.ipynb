# %%
# !pip install pandas numpy plotly scikit-learn nltk

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import plotly.io as pio
pio.renderers.default = 'notebook'  # Change to 'browser' if needed

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
import webbrowser
import os

# %%
app_df = pd.read_csv('Play Store Data.csv')
review_df = pd.read_csv('User Reviews.csv')

# %%
app_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
review_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
app_df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# data cleaning

# %%
# data cleaning
app_df.isnull().sum() # reading the missing value
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
review_df.isnull().sum() # reading the missing value
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
app_df = app_df.dropna(subset =['Rating'])
for column in app_df.columns:
  app_df[column].fillna(app_df[column].mode()[0], inplace=True)

app_df.drop_duplicates(inplace=True)
app_df=app_df[app_df['Rating']<=5]
review_df.dropna(subset =['Translated_Review'])
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %% [markdown]
# convert the install column into the integer and remove the ',' and '+'

# %%
#convert the install column into the integer and remove the ',' and '+'
app_df['Installs'] = app_df['Installs'].str.replace(',', '').str.replace('+', '').astype(int)

# %%
app_df['Price'] = app_df['Price'].str.replace('$', '').astype(float)

# %%
app_df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs            int32
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# Merge the both dataset

# %%
df =pd.merge(app_df,review_df,on ='App',how ='inner')

# %% [markdown]
# Data Transformation

# %%
df
# Out:
#                                  App        Category  Rating Reviews  \
# 0                Coloring book moana  ART_AND_DESIGN     3.9     967
# 1                Coloring book moana  ART_AND_DESIGN     3.9     967
# 2                Coloring book moana  ART_AND_DESIGN     3.9     967
# 3                Coloring book moana  ART_AND_DESIGN     3.9     967
# 4                Coloring book moana  ART_AND_DESIGN     3.9     967
# ...                              ...             ...     ...     ...
# 100174  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 100175  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 100176  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 100177  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
# 100178  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941
#
#                       Size  Installs  Type  Price Content Rating  \
# 0                      14M    500000  Free    0.0       Everyone
# ...

# %%
app_df['Reviews'] = app_df['Reviews'].astype(int)

# %%
app_df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int32
# Size               object
# Installs            int32
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
def convert_size(size):
  if 'M' in size:
      return float(size.replace('M',''))
  elif 'K' in size:
      return float(size.replace('K',''))/1024
  else:
      return np.nan

# %%
app_df['Size']= app_df['Size'].apply(convert_size)

# %%
app_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
app_df['Reviews']= app_df['Reviews'].astype(int )

# %%
#logrithmic
app_df['log_install']=  np.log(app_df['Installs'])
app_df['log_reviews']= np.log(app_df['Reviews'])

# %%
app_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# categories the rating column
def categorize_rating(rating):
    if rating >= 4:
        return 'Top rated app'
    elif rating >= 3:
        return 'Above average'
    elif rating >= 2:
        return 'Average'
    else:
        return 'Below Average'
app_df['Rating_Category'] = app_df['Rating'].apply(categorize_rating)

# %%
app_df['Revenue'] = app_df['Price'] * app_df['Installs']

# %% [markdown]
# sentiment Analysis

# %%
sia = SentimentIntensityAnalyzer()
#positive,Negetive,Neutral,compoud(-1 -> very negative,+1 -> very positive)

# %%
review ="i love this app,its features are very awsome"
sia.polarity_scores(review)
# Out:
# {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'compound': 0.6369}

# %%
review ="i dont like this app,its features are not work as they should work"
sia.polarity_scores(review)
# Out:
# {'neg': 0.161, 'neu': 0.839, 'pos': 0.0, 'compound': -0.2755}

# %%
review =" this app is okay,its features are good"
sia.polarity_scores(review)
# Out:
# {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.4404}

# %%
review_df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
review_df['Sentiment_score'] = review_df['Translated_Review'].apply(lambda x:sia.polarity_scores(str(x))['compound'])

# %%
review_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity  Sentiment_score
# 0  Positive                1.00                0.533333           0.9531
# 1  Positive                0.25                0.288462           0.6597
# 2       NaN                 NaN                     NaN           0.0000
# 3  Positive                0.40                0.875000           0.6249
# 4  Positive                1.00                0.300000           0.6369

# %% [markdown]
#  extracting the year only from Last_update

# %%
app_df['Last Updated'] = pd.to_datetime(app_df['Last Updated'])

# %%
app_df['Year']=app_df['Last Updated'].dt.year

# %% [markdown]
# Data visualization

# %%
html_file_path = './'
if not os.path.exists(html_file_path):
    os.makedirs(html_file_path)

# %% [markdown]
# Top categories apps in playstore respresntaion of barplot

# %%
plot_containers = ""  # Initialize an empty string
def save_plot_as_html(fig, filename, insight):
    global plot_containers
    filepath = os.path.join(html_file_path, filename)
    html_content= pio.to_html(fig, full_html=False, include_plotlyjs='inline')
    plot_containers += f"""
    # <div class="plot-container" id="{filename}" onclick="openPlot('{filename}')">
    #     <div class="plot">{html_content}</div>
    #     <div class="insights">{insight}</div>
    # </div>
    # """

    fig.write_html(filepath, full_html=False, include_plotlyjs='inline')

# %%
plot_width =600
plot_height =500
plot_bg_color = 'black'
text_color = 'white'
title_font={'size':18}
axis_font={'size':14}

# %%
category_counts = app_df['Category'].value_counts().nlargest(10)
fig1 = px.bar(
    x=category_counts.index,
    y=category_counts.values,
    labels={'x': 'Category', 'y': 'Count'},
    title='Top 10 Categories ',
    color=category_counts.index,
    color_discrete_sequence=px.colors.sequential.Plasma,
    width = 400,
    height =300
)
fig1.update_layout(
    plot_bgcolor='black',  # Corrected the typo from 'balck' to 'black'
    paper_bgcolor='black',
    font_color='white',
    title_font={'size':16},
    xaxis=dict(title_font={'size':12}),
    yaxis=dict(title_font={'size':12}),
    margin =dict(l=10,r=10,t=30,b=10)
  )

# fig1.update_traces(marker=dict(pattern=dict(line=dict(color ='white',width=1))))
save_plot_as_html(fig1,'top_10_categories.html','The top categories on the playstore are dominated by tools,entertainment,productivity apps')

# %% [markdown]
# Top categories apps in playstore respresntaion of pie chart

# %%
#fig2
type_counts = app_df['Category'].value_counts().nlargest(10)
fig2 = px.pie(
    values=type_counts.values,
    names=type_counts.index,
    title='Apps category distribution',
    color=category_counts.index,
    color_discrete_sequence=px.colors.sequential.RdBu,
    width = 400,
    height =300
)
fig2.update_layout(
    plot_bgcolor='black',  # Corrected the typo from 'balck' to 'black'
    paper_bgcolor='black',
    font_color='white',
    title_font={'size':16},
    margin =dict(l=10,r=10,t=30,b=10)
  )

# fig1.update_traces(marker=dict(pattern=dict(line=dict(color ='white',width=1))))
save_plot_as_html(fig2,'category_pie_Graph2.html','The top categories on the playstore are dominated by tools,entertainment,productivity apps')

# %% [markdown]
# Type Distribution of playstore(Free/Paid)

# %%
#fig3
type_counts = app_df['Type'].value_counts()
fig3 = px.pie(
    values=type_counts.values,
    names=type_counts.index,
    title='Apps type distribution',
    color_discrete_sequence=px.colors.sequential.RdBu_r,
    width = 400,
    height =300
)
fig3.update_layout(
    plot_bgcolor='black',  # Corrected the typo from 'balck' to 'black'
    paper_bgcolor='black',
    font_color='white',
    title_font={'size':16},
    margin =dict(l=10,r=10,t=30,b=10)
  )

# fig1.update_traces(marker=dict(pattern=dict(line=dict(color ='white',width=1))))
save_plot_as_html(fig3,'type_Graph3.html','Mostly app on the appstore are free ,indicating a strategy to attract users first and monetize through ads')

# %% [markdown]
# Rating Distribution

# %%
#fig4
type_counts = app_df['Rating'].value_counts()
fig4 = px.histogram(
    app_df,
    x ='Rating',
    nbins=20,
    title='Rating distribution',
    color_discrete_sequence=['#665EFA'],
    width = 400,
    height =300
)
fig4.update_layout(
    plot_bgcolor='black',  # Corrected the typo from 'balck' to 'black'
    paper_bgcolor='black',
    font_color='white',
    title_font={'size':16},
    xaxis=dict(title_font={'size':12}),
    yaxis=dict(title_font={'size':12}),
    margin =dict(l=10,r=10,t=30,b=10)
  )

# fig1.update_traces(marker=dict(pattern=dict(line=dict(color ='white',width=1))))
save_plot_as_html(fig4,'Rating_Graph4.html','Rating are skewed towards higher value,suggesting most app are rated fevorably by user')

# %% [markdown]
# Sentiment Distribution

# %%
sentiment_counts = review_df['Sentiment_score'].value_counts()
fig5=px.bar(
    x=sentiment_counts.index,
    y=sentiment_counts.values,
    labels={'x':'Sentiment_score','y':'Count'},
    title='Sentiment Distribution',
    color=sentiment_counts.index,
    color_discrete_sequence=px.colors.sequential.RdBu,
    width = 400,
    height =300
)
fig5.update_layout(
    plot_bgcolor='black',  # Corrected the typo from 'balck' to 'black'
    paper_bgcolor='black',
    font_color='white',
    title_font={'size':16},
    xaxis=dict(title_font={'size':12}),
    yaxis=dict(title_font={'size':12}),
    margin =dict(l=10,r=10,t=30,b=10)
  )

# fig1.update_traces(marker=dict(pattern=dict(line=dict(color ='white',width=1))))
save_plot_as_html(fig5,'Sentiment_Distribution.html','Sentiments reviews show a mix of positive and negative feedback,with a slight positive sentiment')

# %% [markdown]
# Categories Most Installed

# %%
installs_by_counts = app_df.groupby('Category')['Installs'].sum().nlargest(10)
fig6=px.bar(
    x=installs_by_counts.index,
    y=installs_by_counts.values,
    orientation='h',
    labels={'x':'Installs','y':'Category'},
    title='Install by category',
    color=installs_by_counts.index,
    color_discrete_sequence=px.colors.sequential.Blues,
    width = 400,
    height =300
)
fig6.update_layout(
    plot_bgcolor='black',  # Corrected the typo from 'balck' to 'black'
    paper_bgcolor='black',
    font_color='white',
    title_font={'size':16},
    xaxis=dict(title_font={'size':12}),
    yaxis=dict(title_font={'size':12}),
    margin =dict(l=10,r=10,t=30,b=10)
  )

# fig1.update_traces(marker=dict(pattern=dict(line=dict(color ='white',width=1))))
save_plot_as_html(fig6,'Install_graph6.html','The category most installed by the users')

# %% [markdown]
# Updates over the Year

# %%
Update_per_year= app_df['Last Updated'].dt.year.value_counts().sort_index()
fig7 = px.line(
    x=Update_per_year.index,
    y=Update_per_year.values,
    labels={'x': 'Year', 'y': 'Number_of_upadte'},
    title='Number of Updates over the Year',
    color_discrete_sequence=['#AB63FA'],
    width = 400,
    height =300
)
fig7.update_layout(
    plot_bgcolor='black',  # Corrected the typo from 'balck' to 'black'
    paper_bgcolor='black',
    font_color=text_color,
    title_font=title_font,
    xaxis=dict(title_font=axis_font),
    yaxis=dict(title_font=axis_font),
    margin =dict(l=10,r=10,t=30,b=10)
  )

# fig1.update_traces(marker=dict(pattern=dict(line=dict(color ='white',width=1))))
save_plot_as_html(fig7,'Updates_over_the_year_graph07.html','as year passes more update take places or increasing simultaneously')

# %% [markdown]
# Revenue By Category

# %%
Revenue_by_category = app_df.groupby('Category')['Revenue'].sum().nlargest(10)
fig8=px.bar(
    x=Revenue_by_category.index,
    y=Revenue_by_category.values,
    labels={'x':'Category','y':'Revenue'},
    title='Revenue by category',
    color=Revenue_by_category.index,
    color_discrete_sequence=px.colors.sequential.Greens,
    width = 400,
    height =300
)
fig8.update_layout(
    plot_bgcolor='black',  # Corrected the typo from 'balck' to 'black'
    paper_bgcolor='black',
    font_color='white',
    title_font={'size':16},
    xaxis=dict(title_font={'size':12}),
    yaxis=dict(title_font={'size':12}),
    margin =dict(l=10,r=10,t=30,b=10)
  )

# fig1.update_traces(marker=dict(pattern=dict(line=dict(color ='white',width=1))))
save_plot_as_html(fig8,'Revenue_by_category graph6.html','Category such as Business and Productivity leads in revenue generation,Indicating their monitization potential')

# %% [markdown]
# Genres_counts

# %%
Genres_counts = app_df['Genres'].str.split(';',expand=True).stack().value_counts().nlargest(10)
fig9=px.bar(
    x=Genres_counts.index,
    y=Genres_counts.values,
    labels = {'x':'Genres','y':'Count'},
    title ='Top Genres',
    color = Genres_counts.index,
    color_discrete_sequence= px.colors.sequential.OrRd,
    width = 400,
    height = 300
)
fig9.update_layout(
    plot_bgcolor='black',  # Corrected the typo from 'balck' to 'black'
    paper_bgcolor='black',
    font_color='white',
    title_font={'size':16},
    xaxis=dict(title_font={'size':12}),
    yaxis=dict(title_font={'size':12}),
    margin =dict(l=10,r=10,t=30,b=10)
  )

# fig1.update_traces(marker=dict(pattern=dict(line=dict(color ='white',width=1))))
save_plot_as_html(fig9,'Genres_Graph9.html','Action and Casual Genres are most common,reflacting users preferences for engaging and easy to play games')

# %% [markdown]
# Updates Vs Rating

# %%
fig10=px.scatter(
    app_df,
    x='Last Updated',
    y='Rating',
    title='Impact of last update on rating',
    color ='Type',
    color_discrete_sequence= px.colors.qualitative.Vivid  ,
    width = 400,
    height =300
)
fig10.update_layout(
    plot_bgcolor='black',  # Corrected the typo from 'balck' to 'black'
    paper_bgcolor='black',
    font_color='white',
    title_font={'size':16},
    xaxis=dict(title_font={'size':12}),
    yaxis=dict(title_font={'size':12}),
    margin =dict(l=10,r=10,t=30,b=10)
  )

# fig1.update_traces(marker=dict(pattern=dict(line=dict(color ='white',width=1))))
save_plot_as_html(fig10,'updates_vs_rating_graph.html','The scatter plot shows a weak corelation betwween the last update over rating,suggesting the more update is not always result in higher rating')

# %% [markdown]
# Paid-Free Rating Graph

# %%
fig11=px.box(
    app_df,
    x='Type',
    y='Rating',
    title='Rating for Paid vs Free',
    color ='Type',
    color_discrete_sequence= px.colors.qualitative.Pastel  ,
    width = 400,
    height =300
)
fig11.update_layout(
    plot_bgcolor='black',  # Corrected the typo from 'balck' to 'black'
    paper_bgcolor='black',
    font_color='white',
    title_font={'size':16},
    xaxis=dict(title_font={'size':12}),
    yaxis=dict(title_font={'size':12}),
    margin =dict(l=10,r=10,t=30,b=10)
  )

# fig1.update_traces(marker=dict(pattern=dict(line=dict(color ='white',width=1))))
save_plot_as_html(fig11,'PaidFree_rating_graph11.html','Paid apps present the higher rating as compaire to free apps,suggesting that users expect the higer quality from apps they pay for')

# %%
plot_containers_split = plot_containers.split('</div>')

# %%
if len(plot_containers_split) > 1:
  final_plot = plot_containers_split[-2]+'</div>'
else:
  final_plot = plot_containers

# %% [markdown]
# Html doc

# %%
dashboard_html = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Dashboard</title>
    <style>
        body {{
            font-family: Arial, sans-serif;
            background-color: #333;
            color: #fff;
            margin: 0;
            padding: 0
        }}
        .header {{
          display: flex;
          justify-content: center;
          align-items: center;
          padding:20px;
          backgrund-color: #444;
        }}
        .header img {{
          margin:0 10px;
          height:50px
        }}
        .container{{
          display: flex;
          flex-wrap: wrap;
          justify-content: center;
          padding: 20px;
        }}
        .plot-container {{
            boarder:2px solid #555;
            margin: 10px;
            padding: 10px;
            width:{plot_width}px;
            height:{plot_height}px;
            overflow: hidden;
            position: relative;
            cursor: pointer;

        }}
        .insights{{
          display:none;
          position:absolute;
          top:5px;
          right:5px;
          background-color:rgba(0,0,0,0.7);
          padding:5px;
          border-radius:5px;
          color:#fff;

        }}
        .plot-container:hover .insights{{
          display:block;
        }}
    </style>
    <script>
    function openPlot(filename){{
      window.open(filename, '_blank');
    }}
    </script>
    </head>
    <body>
      <div class= 'header'>
          <h1>Google Play Store Review Analytics</h1>
      </div>
      <div class='container'>
          {plots}
      </div>
    </body>
</html>
"""

# %%
final_html = dashboard_html.format(plots=plot_containers,plot_width=plot_width,plot_height=plot_height) # Correcting the variable name from plot_containrs to plot_containers

# %%
dashboard_path = os.path.join(html_file_path, 'web_page.html')
with open(dashboard_path, 'w', encoding='utf-8') as f:
    f.write(final_html)
